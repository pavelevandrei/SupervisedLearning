# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def a(w, x):
    return w[1]*x+w[0]

# %%
a((0, 1), 5)
# Out:
# 5

# %%
# ?np.random.rand

# %% [markdown]
# Генерируем прямую с шумами:

# %%
w_arr = [np.random.rand(2,1) for i in range(10)]
#w_arr = [[0,1]]
#print(np.array(w_arr))
#print(w_arr.shape)

# %%
x = np.linspace(-10, 10, 100)
for w_i in w_arr:
    plt.plot(x, a(w_i, x))
plt.show()

# %%
plt.scatter( [i[0] for i in w_arr ]  , [i[1] for i in w_arr ] )
plt.xlabel('w0')
plt.ylabel('w1')
# Out:
# Text(0, 0.5, 'w1')
