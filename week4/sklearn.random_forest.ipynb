# %% [markdown]
# **Корректность проверена на Python 3.6:**
# + numpy 1.15.4
# + matplotlib 3.0.2
# + sklearn 0.20.2

# %% [markdown]
# # Sklearn

# %% [markdown]
# ## sklearn.ensemble.RandomForestClassifier

# %% [markdown]
# документация:  http://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn import ensemble, model_selection, metrics 

import numpy as np
import pandas as pd

# %% [markdown]
# ### Данные

# %% [markdown]
# Задача на kaggle: https://www.kaggle.com/c/bioresponse
#
# Данные: https://www.kaggle.com/c/bioresponse/data
#
# По данным характеристикам молекулы требуется определить, будет ли дан биологический ответ (biological response).
#
# Признаки нормализаваны.
#
# Для демонстрации используется обучающая выборка из исходных данных train.csv, файл с данными прилагается.

# %%
bioresponce = pd.read_csv('bioresponse.csv', header=0, sep=',')

# %%
bioresponce.head()
# Out:
#    Activity        D1        D2    D3   D4        D5        D6        D7  \
# 0         1  0.000000  0.497009  0.10  0.0  0.132956  0.678031  0.273166
# 1         1  0.366667  0.606291  0.05  0.0  0.111209  0.803455  0.106105
# 2         1  0.033300  0.480124  0.00  0.0  0.209791  0.610350  0.356453
# 3         1  0.000000  0.538825  0.00  0.5  0.196344  0.724230  0.235606
# 4         0  0.100000  0.517794  0.00  0.0  0.494734  0.781422  0.154361
#
#          D8        D9  ...  D1767  D1768  D1769  D1770  D1771  D1772  D1773  \
# 0  0.585445  0.743663  ...      0      0      0      0      0      0      0
# 1  0.411754  0.836582  ...      1      1      1      1      0      1      0
# 2  0.517720  0.679051  ...      0      0      0      0      0      0      0
# 3  0.288764  0.805110  ...      0      0      0      0      0      0      0
# 4  0.303809  0.812646  ...      0      0      0      0      0      0      0
#
#    D1774  D1775  D1776
# 0      0      0      0
# ...

# %%
bioresponce.shape
# Out:
# (3751, 1777)

# %%
bioresponce.columns
# Out:
# Index(['Activity', 'D1', 'D2', 'D3', 'D4', 'D5', 'D6', 'D7', 'D8', 'D9',
#        ...
#        'D1767', 'D1768', 'D1769', 'D1770', 'D1771', 'D1772', 'D1773', 'D1774',
#        'D1775', 'D1776'],
#       dtype='object', length=1777)

# %%
bioresponce_target = bioresponce.Activity.values

# %%
print('bioresponse = 1: {:.2f}\nbioresponse = 0: {:.2f}'.format(sum(bioresponce_target)/(len(bioresponce_target)), 
                1 - sum(bioresponce_target)/(len(bioresponce_target))))
# Out:
# bioresponse = 1: 0.54
# bioresponse = 0: 0.46

# %%
bioresponce_data = bioresponce.iloc[:, 1:]

# %%
bioresponce_data.head()
# Out:
#          D1        D2    D3   D4        D5        D6        D7        D8  \
# 0  0.000000  0.497009  0.10  0.0  0.132956  0.678031  0.273166  0.585445
# 1  0.366667  0.606291  0.05  0.0  0.111209  0.803455  0.106105  0.411754
# 2  0.033300  0.480124  0.00  0.0  0.209791  0.610350  0.356453  0.517720
# 3  0.000000  0.538825  0.00  0.5  0.196344  0.724230  0.235606  0.288764
# 4  0.100000  0.517794  0.00  0.0  0.494734  0.781422  0.154361  0.303809
#
#          D9       D10  ...  D1767  D1768  D1769  D1770  D1771  D1772  D1773  \
# 0  0.743663  0.243144  ...      0      0      0      0      0      0      0
# 1  0.836582  0.106480  ...      1      1      1      1      0      1      0
# 2  0.679051  0.352308  ...      0      0      0      0      0      0      0
# 3  0.805110  0.208989  ...      0      0      0      0      0      0      0
# 4  0.812646  0.125177  ...      0      0      0      0      0      0      0
#
#    D1774  D1775  D1776
# 0      0      0      0
# ...

# %% [markdown]
# ### Модель RandomForestClassifier

# %% [markdown]
# #### Кривые обучения для деревьев небольшой глубиной

# %%
rf_classifier_low_depth = ensemble.RandomForestClassifier(n_estimators = 50, max_depth = 2, random_state = 1)

# %%
train_sizes, train_scores, test_scores = model_selection.learning_curve(rf_classifier_low_depth, bioresponce_data, bioresponce_target, 
                                                                       train_sizes=np.arange(0.1,1., 0.2), 
                                                                       cv=3, scoring='accuracy')

# %%
print(train_sizes)
print(train_scores.mean(axis = 1))
print(test_scores.mean(axis = 1))
# Out:
# [ 250  750 1250 1750 2250]
# [0.74933333 0.71333333 0.68453333 0.69104762 0.69022222]
# [0.62356685 0.64195598 0.65369955 0.66248974 0.66728527]

# %%
pylab.grid(True)
pylab.plot(train_sizes, train_scores.mean(axis = 1), 'g-', marker='o', label='train')
pylab.plot(train_sizes, test_scores.mean(axis = 1), 'r-', marker='o', label='test')
pylab.ylim((0.0, 1.05))
pylab.legend(loc='lower right')

# %% [markdown]
# #### Кривые обучения для деревьев большей глубины

# %%
rf_classifier = ensemble.RandomForestClassifier(n_estimators = 50, max_depth = 10, random_state = 1)

# %%
# %%time
train_sizes, train_scores, test_scores = model_selection.learning_curve(rf_classifier, bioresponce_data, bioresponce_target, 
                                                                       train_sizes=np.arange(0.1,1, 0.2), 
                                                                       cv=3, scoring='accuracy')
# Out:
# Wall time: 5.17 s

# %%
pylab.grid(True)
pylab.plot(train_sizes, train_scores.mean(axis = 1), 'g-', marker='o', label='train')
pylab.plot(train_sizes, test_scores.mean(axis = 1), 'r-', marker='o', label='test')
pylab.ylim((0.0, 1.05))
pylab.legend(loc='lower right')

# %% [markdown]
# #### А.П. Кривые обучения для деревьев еще более высокой сложности

# %%
rf_classifier = ensemble.RandomForestClassifier(n_estimators = 250, max_depth = 20, random_state = 1)

# %%
# %%time
train_sizes, train_scores, test_scores = model_selection.learning_curve(rf_classifier, bioresponce_data, bioresponce_target, 
                                                                       train_sizes=np.arange(0.1,1, 0.2), 
                                                                       cv=3, scoring='accuracy')
# Out:
# Wall time: 27 s

# %%
pylab.grid(True)
pylab.plot(train_sizes, train_scores.mean(axis = 1), 'g-', marker='o', label='train')
pylab.plot(train_sizes, test_scores.mean(axis = 1), 'r-', marker='o', label='test')
pylab.ylim((0.0, 1.05))
pylab.legend(loc='lower right')

# %% [markdown]
# А.П. На тестовой выборке композиция идеально подгоняетс под обучающую выборку любого объема, на тестовой дает в лучшем случе порядка 80% точности.
